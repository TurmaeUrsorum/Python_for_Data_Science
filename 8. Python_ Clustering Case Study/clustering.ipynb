# %%
## for data
import numpy as np
import pandas as pd

## for plotting
import matplotlib.pyplot as plt
import seaborn as sns

## for geospatial
import folium
import geopy

## for machine learning
from sklearn import preprocessing, cluster
import scipy

# %%
dtf = pd.read_csv('https://raw.githubusercontent.com/mdipietro09/DataScience_ArtificialIntelligence_Utils/master/machine_learning/data_stores.csv')
dtf.columns.tolist()
# Out:
# ['Brand',
#  'Store Number',
#  'Store Name',
#  'Ownership Type',
#  'Street Address',
#  'City',
#  'State/Province',
#  'Country',
#  'Postcode',
#  'Phone Number',
#  'Timezone',
#  'Longitude',
#  'Latitude']

# %%
dtf.to_csv('./bahan/data_stores.csv')

# %% [markdown]
# Dataset asli berisi lebih dari 5.000 kota dan 25.000 toko, tetapi untuk tujuan study case ini, Kita akan bekerja hanya dengan satu kota.

# %%
filter = "Las Vegas"
dtf = dtf[dtf["City"]==filter][["City","Street Address","Longitude","Latitude"]].reset_index(drop=True)
dtf = dtf.reset_index().rename(columns={"index":"id"})
dtf.head()
# Out:
#    id       City                     Street Address  Longitude  Latitude
# 0   0  Las Vegas                   4507 Flamingo Rd    -115.20     36.12
# 1   1  Las Vegas  475 E Windmill Lane, Fashion Show    -115.15     36.04
# 2   2  Las Vegas  3200 LAS VEGAS BLVD. S., STE 1795    -115.17     36.13
# 3   3  Las Vegas                8350 W Cheyenne Ave    -115.28     36.22
# 4   4  Las Vegas              3730 LAS VEGAS BLVD S    -115.18     36.11

# %%
dtf.nunique()
# Out:
# id                156
# City                1
# Street Address    140
# Longitude          26
# Latitude           28
# dtype: int64

# %% [markdown]
# Di kawasan itu, ada 156 toko. Untuk melanjutkan kasus bisnis, kita akan mensimulasikan beberapa informasi untuk setiap toko:
#
# - Potensi: total kapasitas dalam hal staf (misalnya 10 berarti toko dapat memiliki hingga 10 karyawan)
# - Staf: tingkat staf saat ini (misalnya 7 berarti toko saat ini beroperasi dengan 7 karyawan)
# - Kapasitas: kapasitas kiri saat ini (misalnya 10–7=3, toko masih dapat menampung 3 karyawan)
# - Biaya: biaya tahunan bagi perusahaan untuk menjaga agar toko tetap beroperasi (“rendah”, “sedang”, “tinggi”)

# %%
dtf["Potential"] = np.random.randint(low=3, high=10+1, size=len(dtf))
dtf["Staff"] = dtf["Potential"].apply(lambda x: int(np.random.rand()*x)+1)
dtf["Capacity"] = dtf["Potential"] - dtf["Staff"]
dtf["Cost"] = np.random.choice(["high","medium","low"], size=len(dtf), p=[0.4,0.5,0.1])
dtf.head()
# Out:
#    id       City                     Street Address  Longitude  Latitude  \
# 0   0  Las Vegas                   4507 Flamingo Rd    -115.20     36.12
# 1   1  Las Vegas  475 E Windmill Lane, Fashion Show    -115.15     36.04
# 2   2  Las Vegas  3200 LAS VEGAS BLVD. S., STE 1795    -115.17     36.13
# 3   3  Las Vegas                8350 W Cheyenne Ave    -115.28     36.22
# 4   4  Las Vegas              3730 LAS VEGAS BLVD S    -115.18     36.11
#
#    Potential  Staff  Capacity    Cost
# 0          7      6         1  medium
# 1          9      6         3  medium
# 2          9      6         3    high
# 3          3      2         1  medium
# 4          3      1         2  medium

# %% [markdown]
# Harap dicatat bahwa ini hanya simulasi, angka-angka ini dihasilkan secara acak dan tidak benar-benar mencerminkan bisnis Starbucks (atau perusahaan lain mana pun).
#
# Sekarang semuanya sudah siap, kita akan mulai dengan menganalisis kasus bisnis, kemudian membangun model pengelompokan dan algoritma rasionalisasi.
#
# Mari kita mulai, ya?

# %% [markdown]
# # EDA

# %% [markdown]
# Anggap saja kita memiliki bisnis ritel dan kita harus menutup beberapa toko. Kita ingin melakukan itu dengan memaksimalkan keuntungan (dengan meminimalkan biaya) dan tanpa memberhentikan staf.
#
# Biaya didistribusikan sebagai berikut:

# %%
x = "Cost"
ax = dtf[x].value_counts().sort_values().plot(kind="barh")
totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
plt.suptitle(x, fontsize=20)
plt.show()

# %%
print(ax.patches)
# Out:
# <Axes.ArtistList of 10 patches>

# %%
x = "Capacity"
ax = dtf[x].value_counts().sort_values().plot(kind="barh")
totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
plt.suptitle(x, fontsize=20)
plt.show()

# %% [markdown]
# Saat ini, hanya sebagian kecil toko yang beroperasi dengan potensi penuh (Kapasitas kiri = 0), artinya ada beberapa dengan staf yang sangat rendah (Kapasitas kiri tinggi):

# %% [markdown]
# Mari kita visualisasikan potongan-potongan informasi itu di peta. Pertama-tama, Kita perlu mendapatkan koordinat area geografis untuk memulai peta. Kita akan melakukannya dengan geopy:

# %%
city = "Las Vegas"
## get location
locator = geopy.geocoders.Nominatim(user_agent="MyCoder")
location = locator.geocode(city)
print(location)
## keep latitude and longitude only
location = [location.latitude, location.longitude]
print("[lat, long]:", location)
# Out:
# Las Vegas, 4, Clark County, Nevada, United States
# [lat, long]: [36.1674263, -115.1484131]

# %% [markdown]
# Kita akan membuat peta dengan folium, package yang sangat nyaman yang memungkinkan kita untuk memplot peta interaktif tanpa perlu memuat shapefile. Setiap toko harus diidentifikasi dengan titik dengan ukuran proporsional dengan staf saat ini dan warna berdasarkan biayanya. Kita juga akan menambahkan sepotong kecil kode HTML ke peta default untuk menampilkan legenda.

# %%
x, y = "Latitude", "Longitude"
color = "Cost"
size = "Staff"
popup = "Street Address"
data = dtf.copy()

## create color column
lst_colors=["red","green","orange"]
lst_elements = sorted(list(dtf[color].unique()))
data["color"] = data[color].apply(lambda x: 
                lst_colors[lst_elements.index(x)])
## create size column (scaled)
scaler = preprocessing.MinMaxScaler(feature_range=(3,15))
data["size"] = scaler.fit_transform(
               data[size].values.reshape(-1,1)).reshape(-1)

## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=11)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]], popup=row[popup],
           color=row["color"], fill=True,
           radius=row["size"]).add_to(map_), axis=1)
## add html legend
legend_html = """<div style="position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;">&nbsp;<b>"""+color+""":</b><br>"""
for i in lst_elements:
     legend_html = legend_html+"""&nbsp;<i class="fa fa-circle 
     fa-1x" style="color:"""+lst_colors[lst_elements.index(i)]+"""">
     </i>&nbsp;"""+str(i)+"""<br>"""
legend_html = legend_html+"""</div>"""
map_.get_root().html.add_child(folium.Element(legend_html))

## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9706092eba221da855c05d3afc449f64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;&quot;&gt;&amp;nbsp;&lt;b&gt;Cost:&lt;/b&gt;&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:red&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;high&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:green&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;low&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:orange&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;medium&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9706092eba221da855c05d3afc449f64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9706092eba221da855c05d3afc449f64 = L.map(
#                 &quot;map_9706092eba221da855c05d3afc449f64&quot;,
#                 {
#                     center: [36.1674263, -115.1484131],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c046dfd7213213e57093a7326bf1086e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c046dfd7213213e57093a7326bf1086e.addTo(map_9706092eba221da855c05d3afc449f64);
#
#
#             var circle_marker_3477ba4f31dcca009ccede07c6035f11 = L.circleMarker(
#                 [36.12, -115.2],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.666666666666666, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9706092eba221da855c05d3afc449f64);
#
#
#         var popup_082bf1be63f342de5d44e15bfd4b3c53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4e119e35e0e300aa73035e4afc006bb = $(`&lt;div id=&quot;html_b4e119e35e0e300aa73035e4afc006bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4507 Flamingo Rd&lt;/div&gt;`)[0];
#                 popup_082bf1be63f342de5d44e15bfd4b3c53.setContent(html_b4e119e35e0e300aa73035e4afc006bb);
#
#
#
#         circle_marker_3477ba4f31dcca009ccede07c6035f11.bindPopup(popup_082bf1be63f342de5d44e15bfd4b3c53)
#         ;
#
#
#
#
#             var circle_marker_e3fdec5cfa251a187f319b6dfbd24fc0 = L.circleMarker(
#                 [36.04, -115.15],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.666666666666666, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9706092eba221da855c05d3afc449f64);
#
#
#         var popup_949a16ccfa165a0cd04d9b92dfbe932b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ded94665b05422a62c214167233ed7f = $(`&lt;div id=&quot;html_2ded94665b05422a62c214167233ed7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;475 E Windmill Lane, Fashion Show&lt;/div&gt;`)[0];
#                 popup_949a16ccfa165a0cd04d9b92dfbe932b.setContent(html_2ded94665b05422a62c214167233ed7f);
#
#
#
#         circle_marker_e3fdec5cfa251a187f319b6dfbd24fc0.bindPopup(popup_949a16ccfa165a0cd04d9b92dfbe932b)
#         ;
#
#
#
#
#             var circle_marker_bcdaf73e697fade74ce93def7f606f60 = L.circleMarker(
#                 [36.13, -115.17],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.666666666666666, &quot;stroke&quot;: true, &quot;weight&quot;: 3}

# %% [markdown]
# Tujuan kita adalah untuk menutup sebanyak mungkin toko berbiaya tinggi (titik merah) dengan memindahkan staf mereka ke toko berbiaya rendah (titik hijau) dengan kapasitas yang terletak di lingkungan yang sama. Akibatnya, kita akan memaksimalkan keuntungan (dengan menutup toko berbiaya tinggi) dan efisiensi (dengan memiliki toko berbiaya rendah yang bekerja dengan kapasitas penuh).
#
# Bagaimana kita bisa mendefinisikan lingkungan tanpa memilih ambang jarak dan batas geografis? Nah, jawabannya adalah… Clustering.

# %% [markdown]
# # Model Building : Clustering and Evaluation

# %% [markdown]
# Di sini, untuk menentukan k yang tepat, Kita akan menggunakan Metode Siku: memplot varians sebagai fungsi dari jumlah cluster dan memilih k yang meratakan kurva.

# %%
X = dtf[["Latitude","Longitude"]]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i 
     in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()

# %% [markdown]
# Kita dapat mencoba dengan k = 5 sehingga algoritma K-Means akan menemukan 5 centroid teoritis. Selain itu, Kita juga akan mengidentifikasi centroid sebenarnya (pengamatan terdekat dengan pusat cluster).

# %%
k = 5
model = cluster.KMeans(n_clusters=k, init='k-means++')
X = dtf[["Latitude","Longitude"]]
## clustering
dtf_X = X.copy()
dtf_X["cluster"] = model.fit_predict(X)
## find real centroids
closest, distances = scipy.cluster.vq.vq(model.cluster_centers_, 
                     dtf_X.drop("cluster", axis=1).values)
dtf_X["centroids"] = 0
for i in closest:
    dtf_X["centroids"].iloc[i] = 1
## add clustering info to the original dataset
dtf[["cluster","centroids"]] = dtf_X[["cluster","centroids"]]
dtf.sample(5)
# Out:
# /tmp/ipykernel_10347/3237973723.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# /tmp/ipykernel_10347/3237973723.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
# /tmp/ipykernel_10347/3237973723.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# /tmp/ipykernel_10347/3237973723.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
# /tmp/ipykernel_10347/3237973723.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# /tmp/ipykernel_10347/3237973723.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
# /tmp/ipykernel_10347/3237973723.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# /tmp/ipykernel_10347/3237973723.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
# /tmp/ipykernel_10347/3237973723.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# /tmp/ipykernel_10347/3237973723.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
#       id       City                                Street Address  Longitude  \
# 53    53  Las Vegas  3333 Blue Diamond Road, Tule Springs Village    -115.18
# 131  131  Las Vegas                            5757 Paradise Road    -115.14
# 34    34  Las Vegas                          2411 West Sahara Ave    -115.18
# 20    20  Las Vegas                          8540 W Desert Inn Rd    -115.28
# 144  144  Las Vegas                       7101 West Craig Road, 1    -115.25
#
#      Latitude  Potential  Staff  Capacity    Cost  cluster  centroids
# 53      36.04          9      9         0  medium        2          0
# 131     36.08          9      6         3  medium        2          0
# 34      36.14          7      5         2    high        2          0
# 20      36.13         10      3         7    high        1          0
# 144     36.24          5      2         3  medium        3          0

# %% [markdown]
# Kita menambahkan dua kolom ke dataset: "cluster" yang menunjukkan cluster apa yang menjadi milik observasi, dan "centroids" yaitu 1 jika pengamatan juga merupakan centroid (paling dekat dengan pusat) dan 0 sebaliknya. Mari kita rencanakan:

# %%
## plot
fig, ax = plt.subplots()
sns.scatterplot(x="Latitude", y="Longitude", data=dtf, 
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief", ax=ax).set_title('Clustering (k='+str(k)+')')
th_centroids = model.cluster_centers_
ax.scatter(th_centroids[:,0], th_centroids[:,1], s=50, c='black', 
           marker="x")

# %% [markdown]
# Terlepas dari algoritma yang Anda gunakan untuk mengelompokkan data, sekarang Anda memiliki kumpulan data dengan dua kolom lagi (“cluster”, “centroids”). Kita dapat menggunakannya untuk memvisualisasikan cluster pada peta, dan kali ini kita akan menampilkan centroid juga menggunakan marker.

# %%
x, y = "Latitude", "Longitude"
color = "cluster"
size = "Staff"
popup = "Street Address"
marker = "centroids"
data = dtf.copy()
## create color column
lst_elements = sorted(list(dtf[color].unique()))
lst_colors = ['#%06X' % np.random.randint(0, 0xFFFFFF) for i in 
              range(len(lst_elements))]
data["color"] = data[color].apply(lambda x: 
                lst_colors[lst_elements.index(x)])
## create size column (scaled)
scaler = preprocessing.MinMaxScaler(feature_range=(3,15))
data["size"] = scaler.fit_transform(
               data[size].values.reshape(-1,1)).reshape(-1)
## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=11)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]], popup=row[popup],
           color=row["color"], fill=True,
           radius=row["size"]).add_to(map_), axis=1)
## add html legend
legend_html = """<div style="position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;">&nbsp;<b>"""+color+""":</b><br>"""
for i in lst_elements:
     legend_html = legend_html+"""&nbsp;<i class="fa fa-circle 
     fa-1x" style="color:"""+lst_colors[lst_elements.index(i)]+"""">
     </i>&nbsp;"""+str(i)+"""<br>"""
legend_html = legend_html+"""</div>"""
map_.get_root().html.add_child(folium.Element(legend_html))
## add centroids marker
lst_elements = sorted(list(dtf[marker].unique()))
data[data[marker]==1].apply(lambda row: 
           folium.Marker(location=[row[x],row[y]], 
           popup=row[marker], draggable=False,          
           icon=folium.Icon(color="black")).add_to(map_), axis=1)
## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_450820f96e2ce1fd49a46a2a56d204e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;&quot;&gt;&amp;nbsp;&lt;b&gt;cluster:&lt;/b&gt;&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#BD74C1&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;0&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#FD6088&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;1&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#B27D36&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;2&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#2E6C2F&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;3&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#DA4672&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;4&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_450820f96e2ce1fd49a46a2a56d204e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_450820f96e2ce1fd49a46a2a56d204e3 = L.map(
#                 &quot;map_450820f96e2ce1fd49a46a2a56d204e3&quot;,
#                 {
#                     center: [36.1674263, -115.1484131],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70c0f15a0d982da751d33938db67002d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70c0f15a0d982da751d33938db67002d.addTo(map_450820f96e2ce1fd49a46a2a56d204e3);
#
#
#             var circle_marker_cd7fd82ed2b3b75aa7374c7f0af733b6 = L.circleMarker(
#                 [36.12, -115.2],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#B27D36&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#B27D36&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.666666666666666, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_450820f96e2ce1fd49a46a2a56d204e3);
#
#
#         var popup_2804a56597e5987f11dd54ed525a6d51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9eaf553b34724fe26a6fff5f14bcc81a = $(`&lt;div id=&quot;html_9eaf553b34724fe26a6fff5f14bcc81a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4507 Flamingo Rd&lt;/div&gt;`)[0];
#                 popup_2804a56597e5987f11dd54ed525a6d51.setContent(html_9eaf553b34724fe26a6fff5f14bcc81a);
#
#
#
#         circle_marker_cd7fd82ed2b3b75aa7374c7f0af733b6.bindPopup(popup_2804a56597e5987f11dd54ed525a6d51)
#         ;
#
#
#
#
#             var circle_marker_2823eecac9fdb221b8dc76e096006e0c = L.circleMarker(
#                 [36.04, -115.15],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#B27D36&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#B27D36&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.666666666666666, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_450820f96e2ce1fd49a46a2a56d204e3);
#
#
#         var popup_667cc270ec9e43dccacd44263dd952fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38395f2796ac0f2b9b29faefde72fa3e = $(`&lt;div id=&quot;html_38395f2796ac0f2b9b29faefde72fa3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;475 E Windmill Lane, Fashion Show&lt;/div&gt;`)[0];
#                 popup_667cc270ec9e43dccacd44263dd952fb.setContent(html_38395f2796ac0f2b9b29faefde72fa3e);
#
#
#
#         circle_marker_2823eecac9fdb221b8dc76e096006e0c.bindPopup(popup_667cc270ec9e43dccacd44263dd952fb)
#         ;
#
#
#
#
#             var circle_marker_b47c336ef3a1735491b397c474e109ad = L.circleMarker(
#                 [36.13, -115.17],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#B27D36&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#B27D36&q

# %% [markdown]
# Sekarang kita memiliki cluster, kita dapat memulai rasionalisasi toko di dalam masing-masing cluster.

# %% [markdown]
# # Store Rationalization
#
# Karena fokus utama artikel ini adalah mengelompokkan data geospasial, Kita akan membuat bagian ini tetap sederhana. Di dalam setiap cluster, Kita akan memilih target potensial (toko berbiaya tinggi) dan hub (toko berbiaya rendah), dan merelokasi staf target di hub sampai yang terakhir mencapai kapasitas penuh. Ketika seluruh staf target dipindahkan, toko bisa ditutup.

# %%
dtf_new = pd.DataFrame()
for c in sorted(dtf["cluster"].unique()):
    dtf_cluster = dtf[dtf["cluster"] == c]

    # hubs and targets
    lst_hubs = dtf_cluster[dtf_cluster["Cost"] == "low"
                           ].sort_values("Capacity").to_dict("records")
    lst_targets = dtf_cluster[dtf_cluster["Cost"] == "high"
                              ].sort_values("Staff").to_dict("records")
    # move targets
    for target in lst_targets:
        for hub in lst_hubs:
            # if hub has space
            if hub["Capacity"] > 0:
                residuals = hub["Capacity"] - target["Staff"]
                # case of hub has still capacity: do next target
                if residuals >= 0:
                    hub["Staff"] += target["Staff"]
                    hub["Capacity"] = hub["Potential"] - hub["Staff"]
                    target["Capacity"] = target["Potential"]
                    target["Staff"] = 0
                    break
                # case of hub is full: do next hub
                else:
                    hub["Capacity"] = 0
                    hub["Staff"] = hub["Potential"]
                    target["Staff"] = -residuals
                    target["Capacity"] = target["Potential"] - target["Staff"]
dtf_new = pd.concat([dtf_new, pd.DataFrame(lst_hubs)], ignore_index=True)
dtf_new = pd.concat([dtf_new, pd.DataFrame(lst_targets)], ignore_index=True)
dtf_new = pd.concat([dtf_new, dtf[dtf["Cost"] == "medium"]], ignore_index=True)

dtf_new = dtf_new.sort_values(["cluster", "Staff"]).reset_index(drop=True)

dtf_new.head()
# Out:
#     id       City                    Street Address  Longitude  Latitude  \
# 0   61  Las Vegas          2585 S. Nellis Blvd., #1    -115.07     36.14
# 1   96  Las Vegas  1925 N. Martin Luther King Blvd.    -115.16     36.19
# 2  135  Las Vegas     2412 E. Desert Inn Road, #100    -115.12     36.13
# 3   38  Las Vegas         751 N. Rancho Drive, #110    -115.18     36.18
# 4  102  Las Vegas       3805 E. Flamingo Road, #100    -115.09     36.11
#
#    Potential  Staff  Capacity    Cost  cluster  centroids
# 0          6      1         5  medium        0          0
# 1          3      1         2  medium        0          0
# 2          4      1         3  medium        0          1
# 3          4      2         2  medium        0          0
# 4          7      2         5  medium        0          0

# %%
dtf_cluster.shape
# Out:
# (11, 11)

# %% [markdown]
# Ini adalah algoritma yang sangat sederhana yang dapat ditingkatkan dalam beberapa cara: misalnya, dengan memasukkan toko-toko berbiaya menengah ke dalam persamaan dan meniru prosesnya ketika toko-toko berbiaya rendah semuanya penuh.
#
# Mari kita lihat berapa banyak toko mahal yang kita tutup dengan proses dasar ini:

# %%
dtf_new["closed"] = dtf_new["Staff"].apply(lambda x: 1 
                                           if x==0 else 0)
print("closed:", dtf_new["closed"].sum())
# Out:
# closed: 0

# %%
x, y = "Latitude", "Longitude"
color = "cluster"
size = "Staff"
popup = "Street Address"
marker = "centroids"
data = dtf_new.copy()
## create color column
lst_elements = sorted(list(dtf[color].unique()))
lst_colors = ['#%06X' % np.random.randint(0, 0xFFFFFF) for i in 
              range(len(lst_elements))]
data["color"] = data[color].apply(lambda x: 
                lst_colors[lst_elements.index(x)])
## create size column (scaled)
scaler = preprocessing.MinMaxScaler(feature_range=(3,15))
data["size"] = scaler.fit_transform(
               data[size].values.reshape(-1,1)).reshape(-1)
## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=11)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]], popup=row[popup],
           color=row["color"], fill=True,
           radius=row["size"]).add_to(map_), axis=1)
## add html legend
legend_html = """<div style="position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;">&nbsp;<b>"""+color+""":</b><br>"""
for i in lst_elements:
     legend_html = legend_html+"""&nbsp;<i class="fa fa-circle 
     fa-1x" style="color:"""+lst_colors[lst_elements.index(i)]+"""">
     </i>&nbsp;"""+str(i)+"""<br>"""
legend_html = legend_html+"""</div>"""
map_.get_root().html.add_child(folium.Element(legend_html))
## add centroids marker
lst_elements = sorted(list(dtf[marker].unique()))
data[data[marker]==1].apply(lambda row: 
           folium.Marker(location=[row[x],row[y]], 
           popup=row[marker], draggable=False,          
           icon=folium.Icon(color="black")).add_to(map_), axis=1)
## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7016445cea223d0c6dfbf0b5ee15e825 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;&quot;&gt;&amp;nbsp;&lt;b&gt;cluster:&lt;/b&gt;&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#711777&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;0&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#992633&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;1&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#B1162F&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;2&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#8C77B4&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;3&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#9938F0&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;4&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7016445cea223d0c6dfbf0b5ee15e825&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7016445cea223d0c6dfbf0b5ee15e825 = L.map(
#                 &quot;map_7016445cea223d0c6dfbf0b5ee15e825&quot;,
#                 {
#                     center: [36.1674263, -115.1484131],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ea07b29b79bfe6f2865cafec9a3cf80 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ea07b29b79bfe6f2865cafec9a3cf80.addTo(map_7016445cea223d0c6dfbf0b5ee15e825);
#
#
#             var circle_marker_d566273f8ecefa99cbbe33a657feead5 = L.circleMarker(
#                 [36.14, -115.07],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#711777&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#711777&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7016445cea223d0c6dfbf0b5ee15e825);
#
#
#         var popup_27843e30c43fab11b19301b86a138528 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f48ce8667abd37ebf814be3142f10d99 = $(`&lt;div id=&quot;html_f48ce8667abd37ebf814be3142f10d99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2585 S. Nellis Blvd., #1&lt;/div&gt;`)[0];
#                 popup_27843e30c43fab11b19301b86a138528.setContent(html_f48ce8667abd37ebf814be3142f10d99);
#
#
#
#         circle_marker_d566273f8ecefa99cbbe33a657feead5.bindPopup(popup_27843e30c43fab11b19301b86a138528)
#         ;
#
#
#
#
#             var circle_marker_075ed993c743e819c957163bd8b17f20 = L.circleMarker(
#                 [36.19, -115.16],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#711777&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#711777&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7016445cea223d0c6dfbf0b5ee15e825);
#
#
#         var popup_5c58b7f8a711e6239c08f27b4f84b849 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a733b9c213230d19691fadb8e83d8ca8 = $(`&lt;div id=&quot;html_a733b9c213230d19691fadb8e83d8ca8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1925 N. Martin Luther King Blvd.&lt;/div&gt;`)[0];
#                 popup_5c58b7f8a711e6239c08f27b4f84b849.setContent(html_a733b9c213230d19691fadb8e83d8ca8);
#
#
#
#         circle_marker_075ed993c743e819c957163bd8b17f20.bindPopup(popup_5c58b7f8a711e6239c08f27b4f84b849)
#         ;
#
#
#
#
#             var circle_marker_21fc2fe1931d58a86c1835f8b675adf1 = L.circleMarker(
#                 [36.13, -115.12],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#711777&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#711777&quot;, &quot;fillOpac
